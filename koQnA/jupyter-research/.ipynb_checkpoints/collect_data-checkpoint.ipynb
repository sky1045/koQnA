# %%
import requests
from lxml import etree
from bs4 import BeautifulSoup
# import StringIO

def list_request(page_no, keyword=''):
    url="http://api.epeople.go.kr/soap/CivilAppealPolicyQnAService?wsdl"
    headers = {'content-type': 'text/xml; charset=UTF-8'}
    body = """
    <soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:ns3="http://apache.org/headers" xmlns:ns2="http://soap.qna.pc.acrc/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true">
       <soap:Header>
       </soap:Header>
       <soap:Body>
          <ns2:getCivilAppealPolicyQnaList>
             <QnaListRequest>
                <type>1</type>
                <nowPageNo>{0}</nowPageNo>
                <keyword>{1}</keyword>
                <pageMg>10</pageMg>
             </QnaListRequest>
          </ns2:getCivilAppealPolicyQnaList>
       </soap:Body>
    </soap:Envelope>
    """.format(page_no, keyword).encode('utf8')
    response = requests.post(url,data=body,headers=headers)
    content = response.content.decode('utf8')
    root = etree.fromstring(content)
    body = root.getchildren()[0]
    resp = body.find('{http://soap.qna.pc.acrc/}getCivilAppealPolicyQnaListResponse')
    resp = resp.find('QnaListResponse')
    infos = resp.findall('QnaListInfo')
    if not infos:
        return None
    result = []
    for child in infos:
        result.append([var.text for var in child.getchildren()])
    return result

def item_request(faq_no, peti_no, civil_no):
    url="http://api.epeople.go.kr/soap/CivilAppealPolicyQnAService?wsdl"
    headers = {'content-type': 'text/xml; charset=UTF-8'}
    body = """
    <soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:ns3="http://apache.org/headers" xmlns:ns2="http://soap.qna.pc.acrc/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:nil="true">
       <soap:Header>

       </soap:Header>
       <soap:Body>
          <ns2:getCivilAppealPolicyQnaItem>
             <QnaItemRequest>
                <faqNo>{0}</faqNo>
                <petiNo>{1}</petiNo>
                <civilNo>{2}</civilNo>
                <type>3</type>
             </QnaItemRequest>
          </ns2:getCivilAppealPolicyQnaItem>
       </soap:Body>
    </soap:Envelope>
    """.format(faq_no, peti_no, civil_no).encode('utf8')
    response = requests.post(url,data=body,headers=headers)
    content = response.content.decode('utf8')
    root = etree.fromstring(content)
    body = root.getchildren()[0]
    resp = body.find('{http://soap.qna.pc.acrc/}getCivilAppealPolicyQnaItemResponse')
    infos = resp.find('QnaItemResponse')
    anc = infos.find('ancName').text
    question = infos.find('content').text
    soup = BeautifulSoup(infos.find('ansContent').text, 'html.parser')
    answer = soup.find_all('span')
    answer = ''.join([x.text for x in answer])
    return anc, question, answer

# %%
li = list_request(9000)
print(li)
# Out:
# [['국토교통부', '1613000', '338705', '1611000008', '2016-09-30 12:55:13', '하천점용허가의 유효기간', '2'], ['국토교통부', '1613000', '141124', '1611000008', '2005-04-18 00:00:00', '하천점용허가 권리·의무 승계 신고', '2'], ['국토교통부', '1613000', '144296', '1611000008', '2007-02-04 18:30:10', '하천에서 골재 채취시 토지점용료 납부 여부', '2'], ['국토교통부', '1613000', '144527', '1611000008', '2007-04-20 11:48:39', '하천점용허가 가능 여부에 대하여 사전 확인이 가능한지요?', '2'], ['국토교통부', '1613000', '338711', '1611000008', '2016-09-30 15:21:51', '하천점용 허가신청시 인근 토지소유자의 동의', '2'], ['국토교통부', '1613000', '338712', '1611000008', '2016-09-30 15:39:51', '하천에서 &lt;지구&gt;의 의미', '2'], ['국토교통부', '1613000', '338715', '1611000008', '2016-09-30 16:45:44', '하천점용허가 기관', '2'], ['국토교통부', '1613000', '144471', '1611000008', '2007-03-22 16:27:42', '하천점용허가시 납부하여야 하는 비용', '2'], ['공정거래위원회', '1130000', '451964', '10', '2018-10-15 14:51:11', '태권도장에 학교 명칭 사용 가부', '2'], ['경찰청', '1320000', '451344', '0060020000', '2018-10-11 10:18:16', '사은품 편취 사기신고', '2']]

# %%
anc, question, answer = item_request(552450, 'A000001570', '3130000')
print(anc, question, answer)
# Out:
# 서울특별시 마포구 장애인 복지카드 신청 방법 및 처리 안내 요청합니다. ○ 장애인복지카드란?장애인에게 발급되는 장애인등록증 및 신용카드나 직불카드와 통합된 등록증을 발급​○ 지원대상​장애인복지법 제32조의 2에 의한 동록 장애인에게는 본인의 희망에 따라 장애인등록증 또는 장애인복지카드중 1종류만을 발급함​○ 장애인복지카드 발급 안내​장애인등록증 등은 (장애인등록증 개선사업을위한 협약)에 의하여 보건복지부,신한카드사, 한국조폐공사간의 협약에 의해서 제작관리○ 온라인 신청 가능한 경우온라인 신청시 장애인 본인이 신청(장애인으로 등록된 장애인 본인만 신청가능​)* 단 복지카드를 신용카드 또는 직불카드 형태로 신청하는 경우 19세 미만의 장애인은 발급대상에서 제외됨​○ 온라인 신청이 불가능한 경우​*신청인이 공인인증서가 없는 경우*신청인이 외국국적인 경우○ 장애인복지카드 신청방법초기상담및 서비스 신청(읍,면,동 주민센터에 방문신청및 온라인 신청) → 접수(읍,면,동 주민센터에서 접수 처리) → 제작(조폐공사) → 교부(읍,면,동 주민센터에서 교부하거나 동기수행)

# %%
import csv
idx = 1
csvfile = open('data.csv', 'w', encoding='utf-8')
csvwriter = csv.writer(csvfile)
while True:
    li = list_request(idx)
    for item in li:
        faq_no, peti_no, civil_no = item[2], item[3], item[1]
        anc, question, answer = item_request(faq_no, peti_no, civil_no)
        print(answer)
        if  answer:
            csvwriter.writerow([anc, question, answer])
    if idx == 3:
        break
    idx += 1
# Out:
# 서울형 주택바우처 신청 자격은 다음과 같습니다.1. 신청대상(아래 기준 모두 충족)o 민간 (보증부)월세 주택 및 고시원 거주자o 전세전환가액이 9,500만원 이하인 가구※ 전세전환가액 = (월 임대료 x 75) + 임대보증금가구원수1인2인3인4인5인중위소득 60%1,024,2051,743,9172,256,0192,768,1223,280,224o 소득인정액이 기준 중위소득의 60% 이하인 가구2. 제외대상o 생계급여 수급자, 의료급여 수급자, 주거급여 수급자o 공공임대주택(국민임대주택, 장기전세주택, 재개발임대주택, 행복주택, 영구임대주택, 전세임대주택, 매입임대주택) 거주자o 가구원이 대학교 재학·휴학생 등 학생으로만 구성된 가구o 외국인으로만 구성된 가구o 가구원이 자동차 2대 이상 소유한 경우(차량종류 불문)o 준주택(기숙사, 오피스텔, 노인복지주택) 거주 가구o 근린생활시설(고시원 제외) 거주 가구o 전세 계약 가구o 전대차(임차인으로부터 재임차) 계약 가구o 부양의무자와 임대차 계약 가구
# 청년희망키움통장 신청방법 및 처리절차는 다음과 같습니다.1. 신청대상(아래 기준 모두 충족)o 생계급여 수급자 또는 의료급여 수급자 o 만 15세 ~ 만 34세 청년 o 근로·사업소득이 기준 중위소득의 20% 이상 가구※ 2019년 기준 중위소득 20% : 341,402원2. 신청방법 및 처리절차 o 신청 장소 : 관할 주민센터 방문 신청o 신청 서류 : 희망키움통장 참여(변경) 신청서, 저축동의서, 개인정보 제공 및 활용 동의서, 소득증빙서류o 조사 실시 및 결과 통보 : 접수일로부터 15일 이내 처리o 통장 개설 : 가까운 하나은행 지점을 통해 통장 개설※ 비대면 계좌(인터넷뱅킹 및 스마트폰뱅킹) 개설 가능3. 제외대상o 주거급여 수급자, 교육급여 수급자, 차상위계층 o 희망키움통장Ⅰ 지급해지자o 유사 자산형성사업(청년내일채움공제, 희망두배청년통장 등)지급 해지자
# 지방세 고충 “납세자보호관”에게 물어 보세요.지방세 납세자보호관은 납세자 입장에서 세무관련 고충이나, 과세 관청의 세무조사 등 납세 관련 어려움을 해소할 수 있도록 지원하는 제도입니다.납세자 보호관은 지방세 관련 고충민원 처리 및 세무상담, 세무조사기간의 연기 및 연장, 체납처분시 권리보호요청에 관한 사항 및 위법·부당한 처분에 대한 시정 및 중지 요구 등 납세자의 권익보호 업무를 수행하게 됩니다.이로써 앞으로 지방세 납세자보호관을 통해 지방세 공무원의 법령 위반, 재량 남용 등 부당한 지방세 부과·징수에 대한 시정요구, 처분중지가 가능해져 지방세 납세자의 권익을 대변할 수 있게 되었습니다. 기타 자세한 사항은 마포구 감사담당관 납세자보호관에 문의하면 됩니다.
# 에코마일리지 상품 배송 및 진행 일정은 다음과 같습니다.신청 상품배송 및 진행 일정온누리 상품권LED 스탠드, 실내보온텐트신청 후, 다음주 수~금요일 도착모바일 문화상품권1~10일 신청자 : 15일 발송11~20일 신청자 : 25일 발송21~31일 신청자 : 다음달 5일 발송예) 1/21~1/31 신청자 : 2월 5일 발송카드 포인트다음달 12일 적립아파트 관리비전달 21일~이번달 20일 신청자 : 다음달 관리비에서 차감예) 1/21~2/20 신청자 : 3월 관리비 차감2/21~3/20 신청자 : 4월 관리비 차감ETAX 마일리지 전환ETAX 사이트 회원가입(에코마일리지와 동일 명의로 가입)나의 ETAX ⟶ 마일리지 관리 ⟶ 공공마일리지 전환하기 ⟶ 에코마일리지 선택(1일 소요)※ 전환 이후 현금 전환, 지방세 납부 등 가능단, 배송일이 공휴일인 경우 익일에 배송합니다.
# 에코마일리지 인센티브 선정 절차는 다음과 같습니다.1. 평가대상월 : 가입월 다음월 부터 6개월 (5월 가입자는 6월~11월까지 평가)2. 인센티브 선정 절차(1) 6개월간 5%이상 절감 대상자 선정(2016년부터) : 1일 ~ 3일(2) 주민등록번호를 등록하도록 SMS발송(기 주민등록번호 등록회원은 제외) : 3일 ~ 10일(3) 주민등록번호 수집 후 주민등록관리부서에 현재 거주지 주소자료 요청 : 10일 ~ 20일(4) 주민등록상의 주소와 회원정보의 주소정보를 자치구청에 통보 : 20일 ~ 25일(5) 주소일치 회원 확정(자치구에서 작업) : 25일 이후(6) 확정된 회원은 ‘마이페이지 ⟶ 나의인센티브내역 ⟶ 상품신청(버튼)’으로 들어가 상품을 신청하시면 자택으로 보내드립니다.
# 회원님께서 새로운 곳으로 이사를 하셔도 에코마일리지 상 주소는 자동으로 변경되지 않습니다. 거주지를 이전하셨을 때는 직접 에코마일리지 홈페이지에서 ‘마이페이지 ⟶ 회원정보수정’란으로 들어가신 후 변경하시거나 동주민센터 또는 해당 구청 환경과에 전화셔서 변경을 요청해주시면 됩니다. 또한 에너지 고객번호도 꼭 함께 수정하셔야 합니다. 회원정보를 수정한 달부터 새로 이사하신 곳의 사용량이 수집되며, 실제 이사하신 날로 소급 적용은 되지 않습니다. 이 점 양해 부탁드립니다. * 주소 및 에너지 고객번호 변경 방법 안내마이페이지 ⟶ ‘회원정보수정’란으로 이동]우편번호 입력 란 옆에 ‘우편번호 조회’ 버튼 클릭팝업이 뜨면 도로명 주소를 검색하여 더블클릭두 번째 단에 상세주소(아파트, 동, 호 등)를 기입하고 최하단의 주소입력을 클릭전기, 도시가스, 상수도의 고객번호를 수정하고 중복검사를 누르고 필요시 대표번호변경신청에 체크한 후 하단의 수정을 누르면 완료됩니다.
# 질문해주신 메시지는 사용량 조회 시 1개의 에너지만 조회될 때 제공되는 메시지입니다. 에코마일리지의 평가대상이 되기 위해서는 전기를 필수로 2개 이상의 에너지사용량이 필요합니다. 때문에 2개 이상의 에너지 사용량이 등록될 수 있도록 조치를 취해 주셔야합니다. 하나만 올라오는 경우는 아래와 같은 원인이 있으니 다음과 같은 조치를 취해 주시기 바랍니다.1. 아파트인 경우1) 경우 1① 원인 : 아파트 코드가 'C'로 시작되고 가스고객번호만 등록되어 있는 경우② 해결방법 : 홈페이지 ⟶ 알림터 ⟶ 정책자료실에서 '에너지사용량 등록요청서'를 작성하여 6개월에 한번 전기/수도사용량을 서울시로 보내주셔야 합니다.(FAX : 02-2133-1021 or 에코마일리지 홈페이지 내 ‘묻고 답하기’ 코너에 '에너지사용량등록요청'의 제목으로 사진으로 첨부) 2) 경우 2① 원인 : 전기만 등록되어 있는 경우(가스고객번호가 등록되어 있지 않거나 잘못 등록되어 있을 때 발생)② 해결방법 : 정확한 가스고객번호를 등록 2. 일반주택인 경우 1) 경우 1① 원인 : 대부분이 고객번호 미등록이나 오기로 인해 사용량이 등재되지 않음② 해결방법 : 고지서의 고객번호를 다시 확인하여 등록한다.
# 에코마일리지는 가족 구성원별로 각자 회원가입을 할 수 있으나, 에코마일리지가 개개인이나 가정의 대표자에게만 적립되는 것은 아닙니다. 온실가스 감축으로 인한 마일리지는 한 세대(고지서 고객번호별)에게 돌아갑니다.
# 가정의 전기, 수도, 도시가스(지역난방 포함)와 같은 에너지 사용량을 6개월 단위로 평가하여 2년 사용량의 평균 대비 5~15%이상 절감하면 절감율에 따라 1~5만원의 마일리지를 제공해드리며 마일리지는 현금전환, 전통시장 온누리 상품권, 모바일 문화상품권 등으로 교환이 가능합니다.(현금전환 및 지방세 납부는 ‘서울시 ETAX’에서 가능합니다.) 정확한 기준과 혜택은 아래 표를 참고해주시기 바랍니다.절감율인센티브5%이상 10%미만1만 마일리지10%이상 15%미만3만 마일리지15%이상5만 마일리지마일리지상품명1만 마일리지3만 마일리지모바일 문화상품권, 아파트 관리비 납부, 친환경 제품, 에코카드 포인트, 기부5만 마일리지전통시장 온누리 상품권, 모바일 문화상품권, 아파트 관리비 납부, 친환경 제품, 에코카드 포인트, 기부
# 주민등록번호를 인증하지 않으실 경우, 실거주지 확인이 불가하여 만일 인센티브 대상자라 하여도 마일리지가 적립되지 않기 때문에 주민등록번호를 인증해주셔야 합니다.▪ 수집 목적 : 인센티브 확정을 위해 회원정보의 주소와 주민등록상의 거주지가 일치하는지를 확인▪ 처리 방법 : 에코마일리지 홈페이지 로그인 ⟶ 마이페이지 ⟶ 회원정보수정 ⟶ 하단으로 이동 ⟶ 주민번호 수집에 동의 ⟶ 주민등록번호 입력 ⟶ 인증하기 ⟶ 수정 버튼 클릭▪ 확인 방법 : 주민등록번호가 입력되었으면 회원정보하단에 입력 란이 나타나지 않습니다.▪ 로그인시 메시지 별 처리 방법1. 로그인을 클릭하면 ‘해당 웹페이지는 표시할 수 없습니다.’⟶ Windows XP의 경우 보안모듈 때문에 나타는 error로 서비스팩3를 설치한 후 로그인2. ‘서면가입 회원으로 실명인증이 필요합니다.’⟶ 주민등록번호와 성명을 입력한 후 인증하기 버튼 클릭가. ‘해당인증번호는 이미 사용되고 있습니다.’⟶ 문의전화 120나. ‘가입자의 동일한 명의로 된 주민등록번호를 입력하십시오.’⟶ 나이스 실명인증에 확인(1600-1522)다. ‘실명인증이 완료되었습니다.’⟶ 인센티브 대상 축하 메시지의 확인 버튼 클릭▪ 최종처리 : 회원정보 수정의 주민등록번호 입력 란으로 자동적으로 이동 됨 ⟶ 주민등록번호 수집에 동의하고 주민등록번호를 입력 ⟶ 인증하기 클릭 후 수정 버튼 클릭 ⟶ ‘수정이 완료되었습니다’ 메시지가 뜨면 완료된 것입니다.※ 참고사항- 회원정보의 주소와 주민등록상의 주소를 확인하여 마감 후 1~2주일 후에 자치구청 환경과에서 마일리지를 확정합니다.(확정일자는 구청 환경과에 확인 바랍니다.)- 에코마일리지가 확정되면 홈페이지에 마일리지가 생성되고 상품을 선택하여 신청하면 됩니다.

# %%
with open('data.csv', newline='', encoding='utf-8') as csvfile:
    data_reader = csv.reader(csvfile)
    csv_data = [row for row in data_reader]
csv_data
# Out:
# [['강원도 고성군',
#   '강원도 고성군 관선시절에 쓰인 1990년 이전 구 고성군 로고 그림과 상징하는 의미가 궁금합니다.\r\n아울러 고성군의 대표 관광지도 같이 소개하여 주십시오.\r\n',
#   ''],
#  ['강원도 고성군',
#   '안녕하세요? \r\n저는 사실상  고성군 OO읍 OO리라는  마을에서  태어나지도  자라지도 않았습니다 \r\n하지만 그곳은 제남편의 고향입니다\r\n몇해전부터 건강문제도 있지만 그져 아름다운 고항이좋아 서울생활을 정리하구\r\n귀촌을 준비하느라 왕복7시간의 긴시간이지만 행복한맘으로 자주 OO리를  찾아 터를준비하고있는  부부입니다\r\n그런데 작년부터였던거  같아요\r\n가끔 소나무숲으로  산책을 갔는데 너무 놀랐어요\r\n수십년인지  수백년인지모를 그런 소나무들은  다캐나가구 잘리구 정말로 너무  무차별하게 산림이  훼손되어가는걸 수개월동안  지켜보다가  이건 뭔가 잘못된 국가적 아니! 강원도의 행정인거같다란생각이  들더군여\r\n지금도 그런 태양광발전사업이라는  명목으로  어느기업인지는  모르겠지만\r\n진행되구있는 모습을 보구있으려니 정말 어이도없구  기가막힐뿐입니다\r\n이런꼴을 보구도  아무런 대응책을못하는 동네어르신들또한  모두들 그져 안타깝게 바라만볼뿐~~\r\n나이드신 동네어르신들의 힘없음을 절실\r\n히 느끼고 너무나도 맘이아픕니다\r\n몇주전에 강원도일대에  산불이나서  많은산림이  허탈하게  훼손된거  온국민이  다알고있죠\r\n수년간 지켜온 산림이 불에탄거나 무분별한 개발허가로 개인의 사업적인 목적으로없어지는 거나  무슨차이겠습니까?\r\n전 돈을목적으로  잘못된걸알면서도 개발을신청한사람이나  허가를하구 관리감독을 소홀히하는 그런 행정이 과연 맞는건지 의구심이듭니다\r\n또한 마을한복판에   개인땅이라구  주변땅주인들의 허락도없이  태양광설치를 허가해준건에대해서도  잘못됐다 생각합니다  이로인해  동네주민들끼리  얼굴붉히고 인심마져흉흉해진 마을로 전락해버렸다면  이건 뭔문제있는 군,도, 나가서는 국가적행정아니구  뭐입니까\r\n개울로 길을내서 덤프트럭이 다니구 좁은2차선도로마을길로  수도없이 큰차들이 다녀 온통 먼지에  도로가옆에 한민가는  안방벽에 금까지갔다구합니다\r\n시골어르신들 옛날분들이라  이런경우 어떻게 어느곳에 불편함을 이야기해야할지도  방법도 모릅니다\r\n그런걸 악이용해서  허가낼때 각호수마다  이장님께 맡겨놓았던 도장으로 다 찍었다구  하더군여  그이장님또한  이렇게까지 난개발이될줄은  몰랐을겁니다\r\n동네발전기금이라구 하는 돈며푼주며 \r\n그또한 그개발업자들이  관래상 줬다구도하더라구여\r\n이런 말도안되는 문제투성이 허가과정 모든것들이  잘못되었음을 전 고발하구\r\n철저한 조사와  관리감독으로  송강리의 푸르름을  지켜주시기를  간곡히  부탁드립니다\r\n할말은  태산같은데  어디서부터 더이야기를 글로써  해야할지 모르겠습니다\r\n두서없는글  끝까지앍어주셔서  감사합니다',
#   ''],
#  ['강원도 고성군', '&lt;장애인 전용구역 불법주차', ''],
#  ['강원도 고성군', '장애인 주차구역에 불법 주차 하였음', ''],
#  ['강원도 고성군', '장애인주차구역위반', ''],
#  ['강원도 고성군', '&lt;장애인 전용구역 불법주차', ''],
#  ['강원도 고성군', '장애인 전용구역 불법주차', ''],
#  ['강원도 고성군', '장애인 구역 불법 주차\r\n\r\n', ''],
#  ['강원도 고성군', ' 장애인구역불법주차', ''],
#  ['강원도 고성군', '장애인 주차구역 앞 주정차로 인하여 장애인전용 차량 주차방해가 발생되어 신고드립니다.\r\n\r\n', ''],
#  ['강원도 고성군', '장애인 주차장 구역 위반 신고', ''],
#  ['강원도 고성군',
#   '안녕하세요, 상수도 관련하며 문의를 드립니다.\r\n\r\n수도 조례법 제29조 2항에 세대별계량기는 각 세대 출입문 외부 벽체의 수도계량기 함에 수평으로 설치 할수 있다.라고 되어있습니다.\r\n\r\n1. 수도계량기함이 필수 적으로 설치 되야하는 건가요?\r\n\r\n2. 공동주택 외부벽체 피트(PIT) 부분이 철판으로 되어있는 경우에 계량기함 설치가 어려운데, 점검구를 통해서 피트를 들어갈수 있으면 계량기함을 설치 안하고 피트 안에 계량기를 설치 해도 되는지 문의 드립니다.\r\n',
#   ''],
#  ['강원도 고성군',
#   '제가 귀어을 준비중인데 문의사항이 있습니다.\r\n고성군에서는 귀농 농업창업 및 주택구입 자금이라는 제도가 있는데, 귀어 창업에 대한\r\n자금지원은 없는 것인가요?\r\n귀농에 대한 창업자금만 가능 한건지 알고 싶습니다.\r\n또한 귀어 창업자금 지원이 되지 않는다면 이부분은 어디서 지원 받을수 있는 곳이\r\n있는지 답변을 부탁 드립니다.\r\n',
#   ''],
#  ['강원도 고성군', '횡단보도 불법 주정차 신고입니다.\r\n', ''],
#  ['강원도 고성군',
#   '고성군 oo 사거리에 있는 차량 신호등 중에 oo으로 진입하는 방향 신호등의 좌회전 신호가 신호 떨어진 후 3~5초면 바뀌어 버려서 신호가 변경 되자마자 급하게 좌회전 하는 수밖에 없습니다. 차 한대가 지나가면 바로 적색등으로 바뀌어 버려서 그 뒤에 서있던 차는 또다시 한참을 기다려서 좌회전 신호로 바뀌길 기다렸다가 바뀌자마자 또 급하게 좌회전 해야되고 아주아주 불편합니다. 좌회전 신호 좀 길게 해주세요. 여름에 차량 통행량 많아지기 전에 변경 부탁드립니다.',
#   ''],
#  ['강원도 고성군',
#   '밤에 가로등이  없어서   어둡고  원암1교 다리 끝 부분에\r\n안전 장치가 없어서  마을로 들어오는 입구에서 사고 날 위험이  있습니다.\r\n가로등  아니면 다리 끝 부분에  형광안전장치 설치  바랍니다.\r\n\r\n',
#   ''],
#  ['강원도 고성군',
#   '부산 오륙도에서 시작하는 1코스부터 50코스까지 완주를 목표로 하고 있는데 마지막 50코스가 재진검문소까지 밖에 걸어서 갈 수 없다고 합니다. \r\n예전에는 통일전망대까지 걸어서 갈 수 있었다고 하는데 이전 정부시절 남북관계의 경색으로 인하여 중단되었다는 얘기를 들었습니다.\r\n최근 DMZ 까지 개방하고 있는 상황에 해파랑길 50코스도 통일전망대까지 걸어갈 수 있도록 부탁드립니다!',
#   ''],
#  ['강원도 고성군',
#   '안녕하세요. 산불 및 각종 민원으로 수고가 많으십니다. 송지호 해수욕장은 해수욕으로 유명하여 많은 관광객이 오는 관광지입니다. 또한 캠핑장도 운영을 하여 캠핑족들 또한 많이 옵니다. . 그런데 올해부터 캠핑장으로 차가 무분별하게 들어오기 시작하였습니다. 사진에서 보시는 바와 같이 차단을 위한 플라스틱 봉이 있었으나 차량의 잦은 출입으로 상당수 파손되어 있으면 잔디 또한 훼손이 많이 되었습니다.\r\n산불로 인해 많이 바쁘실 꺼라 생각합니다.  그렇지만 이 곳 캠핑장 또한 고성군의 소중한 관광 자원이며 자연 환경이라고 생각합니다. 큰 조치 없이 차량이 출입할 수 없도록 차단봉 설치 등 차량출입 제한에 대한 플랜카드 정도로도 상당부분 훼손을 저지할 수 있을거라 생각합니다.\r\n산불로 인해 많은 고생하셨고 바쁘시겠지만 적극적인 행정 활동으로 우리 고성군의 관광 자원이며 자연 환경의 보존에 힘써주시면 감사하겠습니다.',
#   ''],
#  ['강원도 고성군', ' 장애인화징실 입구에 경사로가 없으며 자동문이 아니라 손이 불편한 장애인은 출입이 불가능함\r\n', ''],
#  ['강원도 고성군',
#   '질의 1. EL724 규격에 따라 국내에서 친환경인증을 받은 PLA 빨대는 “사용 후 폐기할 때 재활용 대상 합성수지와 함께 배출해서는 안 된다는 정보를 제공하여야 한다.”라고 규격에 명시가 되어 있어 소비자에게 이러한 정보를 제공해야 합니다. \r\n\r\n이 PLA 빨대를 귀 지자체의 카페 매장 등에서 폐기시 종량제 봉투에 담아 일반 쓰레기로 폐기(매립 시 생분해)하면 되는지요? 아니면 귀 지자체가 정하는 방법이 있다면 알려주시기 바랍니다. \r\n\r\n질의 2. EL724규격으로 국내의 친환경 인증을 받지 않았더라도 PLA 빨대라면 종량제 봉투에 담아 일반 쓰레기로 폐기하면 되는지요? 일부 업체에서는 이 경우 국내 법에 따른 생분해를 이야기하지 못하더라도 음료 등 음식물이 묻었으므로 일반 쓰레기로 배출하여 폐기하면 된다는 이야기를 들은 적이 있습니다. \r\n\r\n보다 깨끗한 환경을 위해 지자체의 조례나 정하는 방법을 확인 요청하니, 답변 부탁드리겠습니다. ',
#   ''],
#  ['서울특별시 마포구',
#   '서울형 주택바우처 신청 자격이 어떻게 되나요?',
#   '서울형 주택바우처 신청 자격은 다음과 같습니다.1. 신청대상(아래 기준 모두 충족)o 민간 (보증부)월세 주택 및 고시원 거주자o 전세전환가액이 9,500만원 이하인 가구※ 전세전환가액 = (월 임대료 x 75) + 임대보증금가구원수1인2인3인4인5인중위소득 60%1,024,2051,743,9172,256,0192,768,1223,280,224o 소득인정액이 기준 중위소득의 60% 이하인 가구2. 제외대상o 생계급여 수급자, 의료급여 수급자, 주거급여 수급자o 공공임대주택(국민임대주택, 장기전세주택, 재개발임대주택, 행복주택, 영구임대주택, 전세임대주택, 매입임대주택) 거주자o 가구원이 대학교 재학·휴학생 등 학생으로만 구성된 가구o 외국인으로만 구성된 가구o 가구원이 자동차 2대 이상 소유한 경우(차량종류 불문)o 준주택(기숙사, 오피스텔, 노인복지주택) 거주 가구o 근린생활시설(고시원 제외) 거주 가구o 전세 계약 가구o 전대차(임차인으로부터 재임차) 계약 가구o 부양의무자와 임대차 계약 가구'],
#  ['서울특별시 마포구',
#   '청년희망키움통장을 신청하고 싶은데 신청방법 및 처리절차는 어떻게 되나요?',
#   '청년희망키움통장 신청방법 및 처리절차는 다음과 같습니다.1. 신청대상(아래 기준 모두 충족)o 생계급여 수급자 또는 의료급여 수급자 o 만 15세 ~ 만 34세 청년 o 근로·사업소득이 기준 중위소득의 20% 이상 가구※ 2019년 기준 중위소득 20% : 341,402원2. 신청방법 및 처리절차 o 신청 장소 : 관할 주민센터 방문 신청o 신청 서류 : 희망키움통장 참여(변경) 신청서, 저축동의서, 개인정보 제공 및 활용 동의서, 소득증빙서류o 조사 실시 및 결과 통보 : 접수일로부터 15일 이내 처리o 통장 개설 : 가까운 하나은행 지점을 통해 통장 개설※ 비대면 계좌(인터넷뱅킹 및 스마트폰뱅킹) 개설 가능3. 제외대상o 주거급여 수급자, 교육급여 수급자, 차상위계층 o 희망키움통장Ⅰ 지급해지자o 유사 자산형성사업(청년내일채움공제, 희망두배청년통장 등)지급 해지자'],
#  ['서울특별시 마포구',
#   '납세자보호관 제도란 무엇인가요?',
#   '지방세 고충 “납세자보호관”에게 물어 보세요.지방세 납세자보호관은 납세자 입장에서 세무관련 고충이나, 과세 관청의 세무조사 등 납세 관련 어려움을 해소할 수 있도록 지원하는 제도입니다.납세자 보호관은 지방세 관련 고충민원 처리 및 세무상담, 세무조사기간의 연기 및 연장, 체납처분시 권리보호요청에 관한 사항 및 위법·부당한 처분에 대한 시정 및 중지 요구 등 납세자의 권익보호 업무를 수행하게 됩니다.이로써 앞으로 지방세 납세자보호관을 통해 지방세 공무원의 법령 위반, 재량 남용 등 부당한 지방세 부과·징수에 대한 시정요구, 처분중지가 가능해져 지방세 납세자의 권익을 대변할 수 있게 되었습니다. 기타 자세한 사항은 마포구 감사담당관 납세자보호관에 문의하면 됩니다.'],
#  ['서울특별시 마포구',
#   '마일리지 상품을 신청했는데 언제 배송되나요?',
#   '에코마일리지 상품 배송 및 진행 일정은 다음과 같습니다.신청 상품배송 및 진행 일정온누리 상품권LED 스탠드, 실내보온텐트신청 후, 다음주 수~금요일 도착모바일 문화상품권1~10일 신청자 : 15일 발송11~20일 신청자 : 25일 발송21~31일 신청자 : 다음달 5일 발송예) 1/21~1/31 신청자 : 2월 5일 발송카드 포인트다음달 12일 적립아파트 관리비전달 21일~이번달 20일 신청자 : 다음달 관리비에서 차감예) 1/21~2/20 신청자 : 3월 관리비 차감2/21~3/20 신청자 : 4월 관리비 차감ETAX 마일리지 전환ETAX 사이트 회원가입(에코마일리지와 동일 명의로 가입)나의 ETAX ⟶ 마일리지 관리 ⟶ 공공마일리지 전환하기 ⟶ 에코마일리지 선택(1일 소요)※ 전환 이후 현금 전환, 지방세 납부 등 가능단, 배송일이 공휴일인 경우 익일에 배송합니다.'],
#  ['서울특별시 마포구',
#   '에코마일리지 인센티브 선정 절차는 어떻게 되나요?',
#   '에코마일리지 인센티브 선정 절차는 다음과 같습니다.1. 평가대상월 : 가입월 다음월 부터 6개월 (5월 가입자는 6월~11월까지 평가)2. 인센티브 선정 절차(1) 6개월간 5%이상 절감 대상자 선정(2016년부터) : 1일 ~ 3일(2) 주민등록번호를 등록하도록 SMS발송(기 주민등록번호 등록회원은 제외) : 3일 ~ 10일(3) 주민등록번호 수집 후 주민등록관리부서에 현재 거주지 주소자료 요청 : 10일 ~ 20일(4) 주민등록상의 주소와 회원정보의 주소정보를 자치구청에 통보 : 20일 ~ 25일(5) 주소일치 회원 확정(자치구에서 작업) : 25일 이후(6) 확정된 회원은 ‘마이페이지 ⟶ 나의인센티브내역 ⟶ 상품신청(버튼)’으로 들어가 상품을 신청하시면 자택으로 보내드립니다.'],
#  ['서울특별시 마포구',
#   '이사를 갔는데, 에코마일리지 회원정보 상 주소를 변경해야 하나요?',
#   '회원님께서 새로운 곳으로 이사를 하셔도 에코마일리지 상 주소는 자동으로 변경되지 않습니다. 거주지를 이전하셨을 때는 직접 에코마일리지 홈페이지에서 ‘마이페이지 ⟶ 회원정보수정’란으로 들어가신 후 변경하시거나 동주민센터 또는 해당 구청 환경과에 전화셔서 변경을 요청해주시면 됩니다. 또한 에너지 고객번호도 꼭 함께 수정하셔야 합니다. 회원정보를 수정한 달부터 새로 이사하신 곳의 사용량이 수집되며, 실제 이사하신 날로 소급 적용은 되지 않습니다. 이 점 양해 부탁드립니다. * 주소 및 에너지 고객번호 변경 방법 안내마이페이지 ⟶ ‘회원정보수정’란으로 이동]우편번호 입력 란 옆에 ‘우편번호 조회’ 버튼 클릭팝업이 뜨면 도로명 주소를 검색하여 더블클릭두 번째 단에 상세주소(아파트, 동, 호 등)를 기입하고 최하단의 주소입력을 클릭전기, 도시가스, 상수도의 고객번호를 수정하고 중복검사를 누르고 필요시 대표번호변경신청에 체크한 후 하단의 수정을 누르면 완료됩니다.'],
#  ['서울특별시 마포구',
#   '‘수급원(전기, 가스, 수도)을 추가로 등록해주시기 바랍니다.’ 라는 메시지를 받았는데 어떻게 해야 하나요?',
#   "질문해주신 메시지는 사용량 조회 시 1개의 에너지만 조회될 때 제공되는 메시지입니다. 에코마일리지의 평가대상이 되기 위해서는 전기를 필수로 2개 이상의 에너지사용량이 필요합니다. 때문에 2개 이상의 에너지 사용량이 등록될 수 있도록 조치를 취해 주셔야합니다. 하나만 올라오는 경우는 아래와 같은 원인이 있으니 다음과 같은 조치를 취해 주시기 바랍니다.1. 아파트인 경우1) 경우 1① 원인 : 아파트 코드가 'C'로 시작되고 가스고객번호만 등록되어 있는 경우② 해결방법 : 홈페이지 ⟶ 알림터 ⟶ 정책자료실에서 '에너지사용량 등록요청서'를 작성하여 6개월에 한번 전기/수도사용량을 서울시로 보내주셔야 합니다.(FAX : 02-2133-1021 or 에코마일리지 홈페이지 내 ‘묻고 답하기’ 코너에 '에너지사용량등록요청'의 제목으로 사진으로 첨부) 2) 경우 2① 원인 : 전기만 등록되어 있는 경우(가스고객번호가 등록되어 있지 않거나 잘못 등록되어 있을 때 발생)② 해결방법 : 정확한 가스고객번호를 등록 2. 일반주택인 경우 1) 경우 1① 원인 : 대부분이 고객번호 미등록이나 오기로 인해 사용량이 등재되지 않음② 해결방법 : 고지서의 고객번호를 다시 확인하여 등록한다."]]
